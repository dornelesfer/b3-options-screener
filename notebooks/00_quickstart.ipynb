# %% [markdown]
# # Quickstart (local)1) Coloque arquivos **COTAHIST de opções** em `data/raw/`.2) Ajuste offsets/colunas em `src/data_b3.py` conforme o **layout** dos seus arquivos.3) Anexe a tabela **BVBG-086** (instrumentos) para obter `strike` e `maturity`.4) Calcule `forward`/`discount` e `IV`; monte a superfície (k,T).

# %%
import pandas as pd, numpy as npfrom pathlib import Pathfrom src.data_b3 import read_cotahist_optionsfrom src.iv_utils import bs_implied_vol, estimate_forward_discountfrom src.surface import build_surface_dayraw_files = list(Path('data/raw').glob('*.txt')) + list(Path('data/raw').glob('*.zip'))print('Arquivos em data/raw:', [f.name for f in raw_files])
